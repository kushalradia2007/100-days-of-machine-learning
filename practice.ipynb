# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Marks-MEP-102.csv')

# %%
df.head()
# Out:
#      f    ID No.                     Name  \
# 0   89  B25DS029          PANDU HARSHITHA
# 1   54  B25CS055           SUBHAMKAR SAHU
# 2  243  B25ME013  ASHTAPUTRE ANANYA ABHAY
# 3  307  B25MT024  SAMAYANA MAHESH GODBOLE
# 4   87  B25DS027         NITISHA DESHMUKH
#
#                                  Discipline           Institute Email ID  \
# 0  Data Science and Artificial Intelligence  panduharshi@iitbhilai.ac.in
# 1          Computer Science and Engineering   subhamkars@iitbhilai.ac.in
# 2                    Mechanical Engineering      aaabhay@iitbhilai.ac.in
# 3                  Mechatronics Engineering    smgodbole@iitbhilai.ac.in
# 4  Data Science and Artificial Intelligence  nitishadesh@iitbhilai.ac.in
#
#        Batch  Sketching and Drawing Lab 1\n30 Marks   \
# 0    Batch 2                                    26.0
# 1    Batch 2                                    25.0
# 2  Batch 6 A                                    28.5
# 3    Batch 3                                    25.0
# 4    Batch 2                                    28.0
#
#    Sketching and Drawing Lab 2\n40 Marks  \
# 0                                   38.0
# 1                                   39.0
# 2                                   38.0
# 3                                   36.0
# 4                                   39.0
#
#    Sketching and Drawing Lab 3\n30 Marks  solid edge1\n30 Marks   ...  \
# 0                                   30.0                    29.0  ...
# 1                                   29.0                    30.0  ...
# 2                                   29.0                    28.0  ...
# 3                                   30.0                    30.0  ...
# 4                                   27.0                    28.0  ...
#
#    3-d printing  laser cutting  welding  End sem (out of 100)  \
# 0             9              8       10                 100.0
# 1             9              9       10                 100.0
# 2             9              8       10                 100.0
# 3            10              9        8                 100.0
# 4            10              9        A                 100.0
#
#    Assignment mark (out of 40) Mid sem (out of 30)  End sem (out of 30) Total  \
# 0                    30.454545           29.188688                 30.0    90
# 1                    29.969697           29.067760                 30.0    89
# 2                    30.878788           28.093905                 30.0    89
# 3                    30.454545           28.422257                 30.0    89
# 4                    30.181818           28.184997                 30.0    88
#
#    Grade Unnamed: 28
# 0     A+         NaN
# 1      A         NaN
# 2      A         NaN
# 3      A         NaN
# 4      A         NaN
#
# [5 rows x 29 columns]

# %%
df.isnull().mean()*100
# Out:
# f                                          0.000000
# ID No.                                     0.000000
# Name                                       0.000000
# Discipline                                 0.321543
# Institute Email ID                         0.321543
# Batch                                      0.000000
# Sketching and Drawing Lab 1\n30 Marks      0.964630
# Sketching and Drawing Lab 2\n40 Marks      1.286174
# Sketching and Drawing Lab 3\n30 Marks      0.964630
# solid edge1\n30 Marks                      1.286174
# solid edge 2 \n30 Marks                    1.607717
# Solid Edge 3\n30 Marks                     1.286174
# Solid Edge 4\n30 Marks                     4.501608
# Solid Edge  exam\n60 Marks                 0.964630
# Exam-mid sem                               0.000000
# Set                                        0.000000
# Normalized score (out of 47)               0.000000
# Unnamed: 17                               96.784566
# cnc                                        1.286174
# 3-d printing                               1.929260
# laser cutting                              1.929260
# welding                                    0.321543
# End sem (out of 100)                       0.321543
# Assignment mark (out of 40)                0.000000
# Mid sem (out of 30)                        0.000000
# End sem (out of 30)                        0.000000
# Total                                      0.000000
# Grade                                      0.000000
# Unnamed: 28                               99.356913
# dtype: float64

# %%
df.shape
# Out:
# (311, 29)

# %%
cols = [var for var in df.columns if df[var].isnull().mean() < 0.05 and df[var].isnull().mean() > 0]
len(cols)
# Out:
# 15

# %%
df[cols].sample(15)
# Out:
#                                           Discipline  \
# 113                           Mechanical Engineering
# 238        Electronics and Communication Engineering
# 262  Materials Science and Metallurgical Engineering
# 49                  Computer Science and Engineering
# 223                           Mechanical Engineering
# 29                          Mechatronics Engineering
# 251                 Computer Science and Engineering
# 144                 Computer Science and Engineering
# 260                           Electrical Engineering
# 285                           Mechanical Engineering
# 193                 Computer Science and Engineering
# 253                           Electrical Engineering
# 10                          Mechatronics Engineering
# 259                 Computer Science and Engineering
# 91          Data Science and Artificial Intelligence
#
#                 Institute Email ID  Sketching and Drawing Lab 1\n30 Marks   \
# 113        smistry@iitbhilai.ac.in                                    20.5
# 238         rsaini@iitbhilai.ac.in                                    17.0
# 262       thussain@iitbhilai.ac.in                                    22.5
# 49      namanayush@iitbhilai.ac.in                                    26.0
# 223        smandal@iitbhilai.ac.in                                    21.5
# 29        amraynil@iitbhilai.ac.in                                    22.5
# 251   kollivenkata@iitbhilai.ac.in                                    26.0
# 144  palavalasapaw@iitbhilai.ac.in                                    23.0
# 260   kamireddybha@iitbhilai.ac.in                                    19.0
# 285          rsoni@iitbhilai.ac.in                                    21.0
# 193     harshvince@iitbhilai.ac.in                                    27.0
# 253  penubodimanoj@iitbhilai.ac.in                                    19.5
# 10           jalaj@iitbhilai.ac.in                                    24.5
# 259   shreyanshpra@iitbhilai.ac.in                                    23.0
# 91    harshitashuk@iitbhilai.ac.in                                    27.5
#
#      Sketching and Drawing Lab 2\n40 Marks  \
# 113                                   34.0
# 238                                    NaN
# 262                                   34.0
# 49                                    39.0
# 223                                   38.0
# 29                                    36.5
# 251                                   33.0
# 144                                   21.0
# 260                                   28.0
# 285                                   32.0
# 193                                   34.0
# 253                                   30.0
# 10                                    39.0
# 259                                   32.0
# 91                                    32.0
#
#      Sketching and Drawing Lab 3\n30 Marks  solid edge1\n30 Marks   \
# 113                                   27.5                    29.0
# 238                                   24.0                    26.0
# 262                                   24.0                    28.0
# 49                                    23.0                    28.0
# 223                                   23.0                    29.0
# 29                                    25.5                    28.0
# 251                                   26.0                    15.0
# 144                                   19.0                    18.0
# 260                                   24.0                    29.0
# 285                                   26.0                    30.0
# 193                                   23.0                    22.0
# 253                                   23.0                    26.0
# 10                                    29.0                    27.0
# 259                                   23.0                    18.0
# 91                                    22.0                    28.0
#
#      solid edge 2 \n30 Marks  Solid Edge 3\n30 Marks   \
# 113                     27.0                     27.0
# 238                     26.0                     27.0
# 262                     26.0                     28.0
# 49                      30.0                     26.0
# 223                     28.0                     29.0
# 29                      27.0                     27.0
# 251                     28.0                     26.0
# 144                     28.0                     26.0
# 260                     28.0                     27.0
# 285                     28.0                     28.0
# 193                     20.0                     28.0
# 253                     28.0                     26.0
# 10                      28.0                     30.0
# 259                     20.0                     24.0
# 91                      26.0                     28.0
#
#      Solid Edge 4\n30 Marks   Solid Edge  exam\n60 Marks    cnc 3-d printing  \
# 113                     30.0                         60.0   9.0           10
# 238                     28.0                         45.0   NaN            9
# 262                     30.0                         60.0   NaN            9
# 49                      29.0                         55.0   9.0            9
# 223                     29.0                         54.0   9.0            8
# 29                      29.0                         55.0   9.0           10
# 251                     27.0                         55.0   9.0            9
# 144                     28.0                         58.0   9.0            9
# 260                     28.0                         60.0   9.5            9
# 285                     30.0                         55.0   9.0            8
# 193                     21.0                         52.0   8.0            8
# 253                     27.0                         60.0   9.0            9
# 10                      28.0                         60.0   9.0           10
# 259                     30.0                         60.0   8.0            8
# 91                      27.0                         54.0  10.0            9
#
#     laser cutting welding  End sem (out of 100)
# 113            10       7                 100.0
# 238            --       8                 100.0
# 262             9       8                  95.0
# 49              8      10                 100.0
# 223             9       7                  95.0
# 29              9       8                 100.0
# 251             9       9                  90.0
# 144             8       9                  95.0
# 260             9       7                 100.0
# 285             8       7                 100.0
# 193             9       9                  90.0
# 253             9       8                 100.0
# 10              8       9                  95.0
# 259             9      10                 100.0
# 91              8      10                 100.0

# %%
len(df[cols].dropna())/len(df)
# Out:
# 0.8906752411575563

# %%
new_df = df[cols].dropna()
df.shape, new_df.shape
# Out:
# ((311, 29), (277, 15))

# %%
new_df.hist(bins=50, density=True, figsize=(12, 12))
